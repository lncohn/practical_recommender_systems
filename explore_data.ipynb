# %%
import os
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

import builder.implicit_ratings_calculator

user_id = '400001'

# %%
query_aggregated_log_data_for_user(user_id)
# Out:
# <QuerySet [{'user_id': '400001', 'content_id': '0475290', 'event': 'addToList', 'count': 25}, {'user_id': '400001', 'content_id': '0475290', 'event': 'buy', 'count': 3}, {'user_id': '400001', 'content_id': '0475290', 'event': 'details', 'count': 108}, {'user_id': '400001', 'content_id': '0475290', 'event': 'genreView', 'count': 39}, {'user_id': '400001', 'content_id': '0475290', 'event': 'moreDetails', 'count': 50}, {'user_id': '400001', 'content_id': '0490215', 'event': 'addToList', 'count': 14}, {'user_id': '400001', 'content_id': '0490215', 'event': 'details', 'count': 63}, {'user_id': '400001', 'content_id': '0490215', 'event': 'genreView', 'count': 23}, {'user_id': '400001', 'content_id': '0490215', 'event': 'moreDetails', 'count': 32}, {'user_id': '400001', 'content_id': '0803096', 'event': 'addToList', 'count': 8}, {'user_id': '400001', 'content_id': '0803096', 'event': 'buy', 'count': 1}, {'user_id': '400001', 'content_id': '0803096', 'event': 'details', 'count': 48}, {'user_
# ...

# %%
calculate_implicit_ratings_for_user('400001')
# Out:
# {'0475290': 6.368715083798882,
#  '0490215': 3.5195530726256985,
#  '0803096': 2.793296089385475,
#  '0918940': 2.122905027932961,
#  '1083452': 3.184357541899441,
#  '1179933': 3.5195530726256985,
#  '1211837': 2.8491620111731844,
#  '1219827': 6.201117318435754,
#  '1289401': 7.988826815642458,
#  '1292566': 5.810055865921788,
#  '1355644': 3.5754189944134076,
#  '1386697': 2.4022346368715084,
#  '1431045': 2.569832402234637,
#  '1473832': 5.139664804469274,
#  '1489889': 6.033519553072626,
#  '1608290': 6.927374301675978,
#  '1619029': 3.016759776536313,
#  '1628841': 2.5139664804469275,
#  '1679335': 5.363128491620111,
#  '1700841': 6.368715083798882,
#  '1711525': 5.977653631284916,
#  '1860213': 6.033519553072626,
#  '1860357': 5.977653631284916,
#  '1878870': 9.664804469273744,
#  '1972591': 4.4692737430167595,
#  '1985949': 5.363128491620111,
#  '2005151': 9.553072625698324,
#  '2025690': 5.921787709497207,
#  '2034800': 2.569832402234637,
#  '2094766': 2.011173184357542,
# ...
